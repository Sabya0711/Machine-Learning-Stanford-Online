# %%
# %run logreg.py
# Out:
# shape of data:  (100, 3)
# [[30.28671077 43.89499752  0.        ]
#  [35.84740877 72.90219803  0.        ]
#  [60.18259939 86.3085521   1.        ]
#  [79.03273605 75.34437644  1.        ]
#  [45.08327748 56.31637178  0.        ]]
# Cost:
#  0.6931471805599453
# Grad:
#  [ -0.1        -12.00921659 -11.26284221]
# Train accuracy 89.0%
# shape of data:  (118, 3)
# [[-0.092742  0.68494   1.      ]
#  [-0.21371   0.69225   1.      ]
#  [-0.375     0.50219   1.      ]
#  [-0.51325   0.46564   1.      ]
#  [-0.52477   0.2098    1.      ]]
# D:\User\GitHub\Machine Learning Stanford Online\02 Logistic Regression\logreg.py:55: RuntimeWarning: divide by zero encountered in log
#   J = -1*(1/m)*(np.log(h).T.dot(y)+np.log(1-h).T.dot(1-y))
# D:\User\GitHub\Machine Learning Stanford Online\02 Logistic Regression\logreg.py:55: RuntimeWarning: divide by zero encountered in log
#   J = -1*(1/m)*(np.log(h).T.dot(y)+np.log(1-h).T.dot(1-y))
# ...
